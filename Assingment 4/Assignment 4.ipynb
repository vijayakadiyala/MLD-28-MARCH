# %% [markdown]
# #####
#  1.1 Write a Python Program(with class concepts) to find the area of the triangle using the below formula.
#
# area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
#
# Function to take the length of the sides of triangle from user should be defined in the parent class and function to calculate the area should be defined in subclass.

# %%
class SidesofTriangle:

    def __init__(self,length_of_sides):
        self.length_of_sides = length_of_sides # list of three numbers


class AreaofTriangle(SidesofTriangle):

    def __init__(self, length_of_sides):
        SidesofTriangle.__init__(self,length_of_sides)
         

    def get_area(self):
        # Function to calculate area if traingle using sides values from parent class
        a, b, c = self.length_of_sides

        
        s = (a + b + c) / 2  # calculate the semi-perimeter
        return (s*(s-a)*(s-b)*(s-c)) ** 0.5  #Area of triangle

# %%
tri = AreaofTriangle([6, 12, 10])
print(tri.get_area())
# Out:
# 29.93325909419153

# %% [markdown]
# ##### 1.2 Write a function filter_long_words() that takes a list of words and an integer n and returns the list of words that are longer than n.

# %%
def filter_long_words(list,n):
    result=[]
    for i in list:
        if len(i)>n:
            result.append(i)
    print('List of words that are longer than '+str(n)+' is '+str(result))
  
list=['vijji','vijaya','balu','kadiyala']
n=5
filter_long_words(list,n)
# Out:
# List of words that are longer than 5 is ['vijaya', 'kadiyala']

# %% [markdown]
# ##### 2.1 Write a Python program using function concept that maps list of words into a list of integers representing the lengths of the corresponding words.
#
# Hint: If a list [ ab,cde,erty] is passed on to the python function output should come as [2,3,4]
#
# Here 2,3 and 4 are the lengths of the words in the list

# %%
def wordlength(inputlist):
    lengths=[]
    for i in inputlist:
        lengths.append(len(i))
    print('lengths of words in '+str(inputlist) +' list is : '+str(lengths))
   
    
list=['vijaya','kadiyala','balaji','valmiki']
wordlength(list)
# Out:
# lengths of words in ['vijaya', 'kadiyala', 'balaji', 'valmiki'] list is : [6, 8, 6, 7]

# %% [markdown]
# ##### 2.2 Write a Python function which takes a character (i.e. a string of length 1) and returns True if it is a vowel, False otherwise.

# %%
def is_vowel(char):
    vowels=['a','e','i','o','u','A','E','I','O','U']
    if char.lower() in vowels:
        return True
    else:
        return False

print(is_vowel('Y'))
print(is_vowel('a'))
# Out:
# False
# True
